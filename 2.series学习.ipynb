# %% [markdown]
# ## series的创建

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5],index=['A','B','C','D','E'],name='月份')    #可以自定义索引和name
print(s)
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# Name: 月份, dtype: int64

# %%
# 通过字典创建
s=pd.Series({'a':1,'b':2,'c':3,'d':4,'e':5})
print(s)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
